# %%
# First, set up imports and paths
import sys
import os

sys.path.append("/home/jovyan/api")  # Add api directory to Python path

from jobs import process_with_marker
import hashlib
from datetime import datetime
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient("mongodb://db:27017/")
db = client["chelle"]
raw_assets = db["raw_assets"]


# Function to simulate file upload and create asset record
def setup_test_file(file_path: str):
    # Read file and calculate hash
    with open(file_path, "rb") as f:
        content = f.read()
        file_hash = hashlib.sha256(content).hexdigest()

    # Get file details
    filename = os.path.basename(file_path)
    file_size = len(content)
    file_ext = os.path.splitext(filename)[1].lower()

    # Determine mime type
    mime_types = {
        ".pdf": "application/pdf",
        ".docx": "application/vnd.openxmlformats-officedocument.wordprocessingml.document",
    }
    file_type = mime_types.get(file_ext, "application/octet-stream")

    # Save file to filestore
    raw_dir = "/home/jovyan/api/filestore/raw"
    os.makedirs(raw_dir, exist_ok=True)
    stored_filename = f"{file_hash}{file_ext}"
    stored_path = os.path.join(raw_dir, stored_filename)

    with open(stored_path, "wb") as f:
        f.write(content)

    # Create asset record
    asset_record = {
        "original_name": filename,
        "stored_name": stored_filename,
        "file_path": stored_path,
        "file_hash": file_hash,
        "file_type": file_type,
        "file_size": file_size,
        "upload_date": datetime.now(),
        "status": "uploaded",
        "processed": False,
    }

    # Insert or update record
    raw_assets.update_one({"file_hash": file_hash}, {"$set": asset_record}, upsert=True)

    return file_hash


# Test with a file
test_file = "/home/jovyan/nb/Health Byte_ Product Roadmap.docx"  # Replace with your test file path
file_hash = setup_test_file(test_file)

# Process with marker
result = process_with_marker(file_hash)

# Check results
asset = raw_assets.find_one({"file_hash": file_hash})
print("Status:", asset.get("status"))
print("Processed:", asset.get("processed"))
print("Processing details:", asset.get("processing_details"))

# If processed successfully, check the extracted content
if asset.get("processed"):
    processed_paths = asset.get("processed_paths", {})

    # Check markdown content
    if "markdown" in processed_paths:
        with open(processed_paths["markdown"], "r") as f:
            print("\nFirst 500 characters of markdown content:")
            print(f.read(500))

    # Check images
    if "images" in processed_paths:
        print("\nExtracted images:")
        for img_name, img_path in processed_paths["images"].items():
            print(f"- {img_name}: {img_path}")
# Out:
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Starting topology monitoring"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e73, topology_type: Unknown, servers: []>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e73, topology_type: Unknown, servers: [<ServerDescription ('db', 27017) server_type: Unknown, rtt: None>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "serverHost": "db", "serverPort": 27017, "message": "Starting server monitoring"}
# DEBUG:pymongo.connection:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Connection pool created", "serverHost": "db", "serverPort": 27017}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverHost": "db", "serverPort": 27017, "awaited": false, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": false, "durationMS": 1.1173749953741208, "reply": "{\"helloOk\": true, \"ismaster\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:24:48.748Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.connection:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Connection pool ready", "serverHost": "db", "serverPort": 27017}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e73, topology_type: Unknown, servers: [<ServerDescription ('db', 27017) server_type: Unknown, rtt: None>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e73, topology_type: Single, servers: [<ServerDescription ('db', 27017) server_type: Standalone, rtt: 0.0011173749953741208>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.serverSelection:{"message": "Server selection started", "selector": "<function writable_server_selector at 0xffff9c0ded40>", "operation": "update", "topologyDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e73, topology_type: Single, servers: [<ServerDescription ('db', 27017) server_type: Standalone, rtt: 0.0011173749953741208>]>", "clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}}
# DEBUG:pymongo.serverSelection:{"message": "Server selection succeeded", "selector": "<function writable_server_selector at 0xffff9c0ded40>", "operation": "update", "topologyDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e73, topology_type: Single, servers: [<ServerDescription ('db', 27017) server_type: Standalone, rtt: 0.0011173749953741208>]>", "clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "serverHost": "db", "serverPort": 27017}
# DEBUG:pymongo.connection:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Connection checkout started", "serverHost": "db", "serverPort": 27017}
# DEBUG:pymongo.connection:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Connection created", "serverHost": "db", "serverPort": 27017, "driverConnectionId": 1}
# DEBUG:pymongo.connection:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Connection ready", "serverHost": "db", "serverPort": 27017, "driverConnectionId": 1, "durationMS": 0.0005053750064689666}
# DEBUG:pymongo.connection:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Connection checked out", "serverHost": "db", "serverPort": 27017, "driverConnectionId": 1, "durationMS": 0.002220916998339817}
# DEBUG:pymongo.command:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Command started", "command": "{\"update\": \"raw_assets\", \"ordered\": true, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"UJ7C6febRAylUqBq6wKGOA==\", \"subType\": \"04\"}}}, \"$db\": \"chelle\", \"updates\": [{\"q\": {\"file_hash\": \"f0d2591e65a7e60e4c0dc5e4656a95905e4e891215cf134f61ebf6e98cdbc1f7\"}, \"u\": {\"$set\": {\"original_name\": \"Health Byte_ Product Roadmap.docx\", \"stored_name\": \"f0d2591e65a7e60e4c0dc5e4656a95905e4e891215cf134f61ebf6e98cdbc1f7.docx\", \"file_path\": \"/home/jovyan/api/filestore/raw/f0d2591e65a7e60e4c0dc5e4656a95905e4e891215cf134f61ebf6e98cdbc1f7.docx\", \"file_hash\": \"f0d2591e65a7e60e4c0dc5e4656a95905e4e891215cf134f61ebf6e98cdbc1f7\", \"file_type\": \"application/vnd.openxmlformats-officedocument.wordprocessingml.document\", \"file_size\": 156537, \"upload_date\": {\"$date\": \"2024-11-01T15:24:48.752Z\"}, \"status\": \"uploaded\"}}, \"upsert\": true}]}", "commandName": "update", "databaseName": "chelle", "requestId": 2044897763, "operationId": 2044897763, "driverConnectionId": 1, "serverConnectionId": 33, "serverHost": "db", "serverPort": 27017}
# DEBUG:pymongo.command:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Command succeeded", "durationMS": 2.06, "reply": "{\"n\": 1, \"nModified\": 1, \"ok\": 1.0}", "commandName": "update", "databaseName": "chelle", "requestId": 2044897763, "operationId": 2044897763, "driverConnectionId": 1, "serverConnectionId": 33, "serverHost": "db", "serverPort": 27017}
# DEBUG:pymongo.connection:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "message": "Connection checked in", "serverHost": "db", "serverPort": 27017, "driverConnectionId": 1}
# INFO:jobs:Starting processing for file f0d2591e65a7e60e4c0dc5e4656a95905e4e891215cf134f61ebf6e98cdbc1f7
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "message": "Starting topology monitoring"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: []>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "message": "Starting server monitoring"}
# DEBUG:pymongo.connection:{"clientId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "message": "Connection pool created", "serverHost": "localhost", "serverPort": 27017}
# DEBUG:pymongo.serverSelection:{"message": "Server selection started", "selector": "<function writable_server_selector at 0xffff9c0ded40>", "operation": "update", "topologyDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}}
# DEBUG:pymongo.serverSelection:{"message": "Waiting for suitable server to become available", "selector": "<function writable_server_selector at 0xffff9c0ded40>", "operation": "update", "topologyDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "remainingTimeMS": 29}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.1908750020666048, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.7395000031683594, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.4041249960428104, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.542917001643218, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.9438750023255125, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.8630830018082634, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 0.49104100617114455, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.7856250051409006, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 0.9447500051464885, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.1265000066487119, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 0.7156250067055225, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.4351249992614612, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.2432910007191822, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 0.48237500595860183, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.3858749880455434, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.332208004896529, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.6337090055458248, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 2.6337500021327287, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 2.3925829882500693, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 0.6152499991003424, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 10013.277172009111, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:24:58.763Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.0043329966720194, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 0.9078330040210858, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.604083998245187, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 71
#      68 file_hash = setup_test_file(test_file)
#      70 # Process with marker
# ---> 71 result = process_with_marker(file_hash)
#      73 # Check results
#      74 asset = raw_assets.find_one({'file_hash': file_hash})
#
# File ~/api/jobs.py:194, in process_with_marker(file_hash)
#     191 logger.info(f"Starting processing for file {file_hash}")
#     193 # Update status to processing
# --> 194 update_asset_status(file_hash, 'processing')
#     196 db = init_mongo()
#     197 assets = db['raw_assets']
#
# File ~/api/jobs.py:32, in update_asset_status(file_hash, status, error)
#      29 if status == 'complete':
#      30     update_data['processed_date'] = datetime.now()
# ---> 32 assets.update_one(
#      33     {'file_hash': file_hash},
#      34     {'$set': update_data}
#      35 )
#      36 logger.debug(f"Updated status for {file_hash} to {status}")
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:1312, in Collection.update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, hint, session, let, comment)
#    1308 common.validate_list_or_none("array_filters", array_filters)
#    1310 write_concern = self._write_concern_for(session)
#    1311 return UpdateResult(
# -> 1312     self._update_retryable(
#    1313         filter,
#    1314         update,
#    1315         _Op.UPDATE,
#    1316         upsert,
#    1317         write_concern=write_concern,
#    1318         bypass_doc_val=bypass_document_validation,
#    1319         collation=collation,
#    1320         array_filters=array_filters,
#    1321         hint=hint,
#    1322         session=session,
#    1323         let=let,
#    1324         comment=comment,
#    1325     ),
#    1326     write_concern.acknowledged,
#    1327 )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:1107, in Collection._update_retryable(self, criteria, document, operation, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, let, comment)
#    1085 def _update(
#    1086     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#    1087 ) -> Optional[Mapping[str, Any]]:
#    1088     return self._update(
#    1089         conn,
#    1090         criteria,
#    (...)
#    1104         comment=comment,
#    1105     )
# -> 1107 return self._database.client._retryable_write(
#    1108     (write_concern or self.write_concern).acknowledged and not multi,
#    1109     _update,
#    1110     session,
#    1111     operation,
#    1112 )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1898, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1884 """Execute an operation with consecutive retries if possible
#    1885
#    1886 Returns func()'s return value on success. On error retries the same
#    (...)
#    1895 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1896 """
#    1897 with self._tmp_session(session) as s:
# -> 1898     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1784, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1779 # Ensure that the options supports retry_writes and there is a valid session not in
#    1780 # transaction, otherwise, we will not support retry behavior for this txn.
#    1781 retryable = bool(
#    1782     retryable and self.options.retry_writes and session and not session.in_transaction
#    1783 )
# -> 1784 return self._retry_internal(
#    1785     func=func,
#    1786     session=session,
#    1787     bulk=bulk,
#    1788     operation=operation,
#    1789     retryable=retryable,
#    1790     operation_id=operation_id,
#    1791 )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2662, in _ClientConnectionRetryable._write(self)
#    2660 max_wire_version = 0
#    2661 is_mongos = False
# -> 2662 self._server = self._get_server()
#    2663 with self._client._checkout(self._server, self._session) as conn:
#    2664     max_wire_version = conn.max_wire_version
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2645, in _ClientConnectionRetryable._get_server(self)
#    2640 def _get_server(self) -> Server:
#    2641     """Retrieves a server object based on provided object context
#    2642
#    2643     :return: Abstraction to connect to server
#    2644     """
# -> 2645     return self._client._select_server(
#    2646         self._server_selector,
#    2647         self._session,
#    2648         self._operation,
#    2649         address=self._address,
#    2650         deprioritized_servers=self._deprioritized_servers,
#    2651         operation_id=self._operation_id,
#    2652     )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1649, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1647             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1648     else:
# -> 1649         server = topology.select_server(
#    1650             server_selector,
#    1651             operation,
#    1652             deprioritized_servers=deprioritized_servers,
#    1653             operation_id=operation_id,
#    1654         )
#    1655     return server
#    1656 except PyMongoError as exc:
#    1657     # Server selection errors in a transaction are transient.
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/topology.py:398, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     388 def select_server(
#     389     self,
#     390     selector: Callable[[Selection], Selection],
#    (...)
#     395     operation_id: Optional[int] = None,
#     396 ) -> Server:
#     397     """Like select_servers, but choose a random server if several match."""
# --> 398     server = self._select_server(
#     399         selector,
#     400         operation,
#     401         server_selection_timeout,
#     402         address,
#     403         deprioritized_servers,
#     404         operation_id=operation_id,
#     405     )
#     406     if _csot.get_timeout():
#     407         _csot.set_rtt(server.description.min_round_trip_time)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/topology.py:376, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     367 def _select_server(
#     368     self,
#     369     selector: Callable[[Selection], Selection],
#    (...)
#     374     operation_id: Optional[int] = None,
#     375 ) -> Server:
# --> 376     servers = self.select_servers(
#     377         selector, operation, server_selection_timeout, address, operation_id
#     378     )
#     379     servers = _filter_servers(servers, deprioritized_servers)
#     380     if len(servers) == 1:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/topology.py:283, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     280     server_timeout = server_selection_timeout
#     282 with self._lock:
# --> 283     server_descriptions = self._select_servers_loop(
#     284         selector, server_timeout, operation, operation_id, address
#     285     )
#     287     return [
#     288         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     289     ]
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/topology.py:357, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     351 self._request_check_all()
#     353 # Release the lock and wait for the topology description to
#     354 # change, or for a timeout. We won't miss any changes that
#     355 # came after our most recent apply_selector call, since we've
#     356 # held the lock until now.
# --> 357 self._condition.wait(common.MIN_HEARTBEAT_INTERVAL)
#     358 self._description.check_compatible()
#     359 now = time.monotonic()
#
# File /opt/conda/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.155124991782941, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 10002.791837992845, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:25:08.769Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 2.1455829992191866, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# ...
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.7265420028707013, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 10010.657587001333, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:31:19.260Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.1484999995445833, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 10014.995213001384, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:31:29.277Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 4.059500002767891, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 9998.912046998157, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:31:39.293Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.0592080070637167, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 10010.356171012972, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:31:49.306Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.0057079925900325, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 10008.278046996566, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:31:59.318Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.5069169894559309, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 10000.258796004346, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:32:09.322Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 0.5836250056745484, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 10014.516711991746, "reply": "{\"isWritablePrimary\": true, \"topologyVersion\": {\"processId\": {\"$oid\": \"6724f21d82e6cdec57b3651a\"}}, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 100000, \"localTime\": {\"$date\": \"2024-11-01T15:32:19.339Z\"}, \"logicalSessionTimeoutMinutes\": 30, \"connectionId\": 31, \"maxWireVersion\": 25, \"ok\": 1.0}", "message": "Server heartbeat succeeded"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "driverConnectionId": 1, "serverConnectionId": 31, "serverHost": "db", "serverPort": 27017, "awaited": true, "message": "Server heartbeat started"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "serverHost": "localhost", "serverPort": 27017, "awaited": false, "durationMS": 1.934667001478374, "failure": "\"AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')\"", "message": "Server heartbeat failed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e74"}, "previousDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "newDescription": "<TopologyDescription id: 6724f2c0a8704f1f0cbd0e74, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>", "message": "Topology description changed"}
# DEBUG:pymongo.topology:{"topologyId": {"$oid": "6724f2c0a8704f1f0cbd0e73"}, "serverHost": "db", "serverPort": 27017, "awaited": true, "durationMS": 8069.014836990391, "failure": "\"_OperationCancelled('operation cancelled')\"", "message": "Server heartbeat failed"}

# %%
# !pip uninstall PyMuPDF -y
# !pip install PyMuPDF==1.22.0
# Out:
# Found existing installation: PyMuPDF 1.24.13
# Uninstalling PyMuPDF-1.24.13:
#   Successfully uninstalled PyMuPDF-1.24.13
# Collecting PyMuPDF==1.22.0
#   Downloading PyMuPDF-1.22.0-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (8.3 kB)
# Downloading PyMuPDF-1.22.0-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 52.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.22.0
